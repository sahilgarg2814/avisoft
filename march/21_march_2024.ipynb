# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import numpy as np
import statsmodels.api as sm

# %%
df1=pd.read_csv(r"D:\datasets2\50_Startups.csv")
df1
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df2=pd.get_dummies(data=df1,prefix=['State'],drop_first=True,dtype=int)
df2
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit  State_Florida  \
# 0   165349.20       136897.80        471784.10  192261.83              0
# 1   162597.70       151377.59        443898.53  191792.06              0
# 2   153441.51       101145.55        407934.54  191050.39              1
# 3   144372.41       118671.85        383199.62  182901.99              0
# 4   142107.34        91391.77        366168.42  166187.94              1
# 5   131876.90        99814.71        362861.36  156991.12              0
# 6   134615.46       147198.87        127716.82  156122.51              0
# 7   130298.13       145530.06        323876.68  155752.60              1
# 8   120542.52       148718.95        311613.29  152211.77              0
# 9   123334.88       108679.17        304981.62  149759.96              0
# 10  101913.08       110594.11        229160.95  146121.95              1
# 11  100671.96        91790.61        249744.55  144259.40              0
# ...

# %%
df3=df2.drop(['Profit'],axis=1)
df3
# Out:
#     R&D Spend  Administration  Marketing Spend  State_Florida  State_New York
# 0   165349.20       136897.80        471784.10              0               1
# 1   162597.70       151377.59        443898.53              0               0
# 2   153441.51       101145.55        407934.54              1               0
# 3   144372.41       118671.85        383199.62              0               1
# 4   142107.34        91391.77        366168.42              1               0
# 5   131876.90        99814.71        362861.36              0               1
# 6   134615.46       147198.87        127716.82              0               0
# 7   130298.13       145530.06        323876.68              1               0
# 8   120542.52       148718.95        311613.29              0               1
# 9   123334.88       108679.17        304981.62              0               0
# 10  101913.08       110594.11        229160.95              1               0
# ...

# %%
xtrain,xtest,ytrain,ytest=train_test_split(df3,df1['Profit'],test_size=0.3,random_state=101)

# %%
model1=LinearRegression()
model1.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
predictions=model1.predict(xtest)
predictions
# Out:
# array([ 85610.28281215, 155888.39676572, 118955.25250493,  97321.71949346,
#        120058.71468302, 191229.46901742, 115589.05335197,  61472.62238231,
#         68398.23852829,  45017.90092841, 116555.37958019, 111205.46598438,
#        166339.57762328,  45886.05016275, 133819.21111256])

# %%
print("models accuracy: ",r2_score(ytest,predictions))
# Out:
# models accuracy:  0.9241937845107014

# %%
def backward_elimination(X, y, significance_level=0.05):
    num_features = X.shape[1]
    for i in range(0, num_features):
        regressor_OLS = sm.OLS(y, X).fit()
        max_p_value = max(regressor_OLS.pvalues)
        if max_p_value > significance_level:
            index_max_p_value = np.where(regressor_OLS.pvalues == max_p_value)[0][0]
            X = np.delete(X, index_max_p_value, 1)
    return X

print(backward_elimination(df3,df1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 11
#       8             X = np.delete(X, index_max_p_value, 1)
#       9     return X
# ---> 11 print(backward_elimination(df3,df1))
#
# Cell In[21], line 4, in backward_elimination(X, y, significance_level)
#       2 num_features = X.shape[1]
#       3 for i in range(0, num_features):
# ----> 4     regressor_OLS = sm.OLS(y, X).fit()
#       5     max_p_value = max(regressor_OLS.pvalues)
#       6     if max_p_value > significance_level:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\statsmodels\regression\linear_model.py:923, in OLS.__init__(self, endog, exog, missing, hasconst, **kwargs)
#     920     msg = ("Weights are not supported in OLS and will be ignored"
#     921            "An exception will be raised in the next version.")
#     922     warnings.warn(msg, ValueWarning)
# ...
